# %%
import numpy as np
import matplotlib.pyplot as plt

# Define parameters
h = np.arange(0.1, 1.01, 0.05)  # step size
x_start, x_end = 0, 2
current_x, current_y = None, None

def f(x, y):      # Function representing dy/dx = -2y
    return -2 * y

plt.figure()

for i in range(len(h)):
    hx = h[i]
    num_steps = int((x_end - x_start) / hx)

    x_values = np.linspace(x_start, x_end, num_steps + 1)
    y_values = np.zeros(num_steps + 1)
    y_values[0] = 1  # y(0) = 1     # Initial condition

    for k in range(num_steps):    # Implement Euler's method
        y_values[k + 1] = y_values[k] + hx * f(x_values[k], y_values[k])

    if i == 0:
        current_x = x_values
        current_y = y_values
        plt.plot(current_x, current_y, label = 'First Run')
        continue 
    
    interp_y = np.interp(current_x, x_values, y_values)
    err = np.abs(interp_y - current_y)
    tot_err = np.sum(err)
    print(f'Step Size: {hx:.2f}       Total Error: {tot_err:.5f}')
    plt.plot(x_values, y_values, label = f'h = {hx:.2f}')
    

plt.xlabel('x')
plt.ylabel('y')
plt.title("Approximation of dy/dx = -2y using Euler's Method")
plt.show()
# Out:
# Step Size: 0.15       Total Error: 0.12468
# Step Size: 0.20       Total Error: 0.08031
# Step Size: 0.25       Total Error: 0.25318
# Step Size: 0.30       Total Error: 0.60100
# Step Size: 0.35       Total Error: 0.81741
# Step Size: 0.40       Total Error: 0.88508
# Step Size: 0.45       Total Error: 1.43858
# Step Size: 0.50       Total Error: 1.39988
# Step Size: 0.55       Total Error: 1.83623
# Step Size: 0.60       Total Error: 2.23868
# Step Size: 0.65       Total Error: 2.80152
# Step Size: 0.70       Total Error: 3.58677
# Step Size: 0.75       Total Error: 4.34194
# Step Size: 0.80       Total Error: 5.24494
# Step Size: 0.85       Total Error: 6.21794
# Step Size: 0.90       Total Error: 7.30464
# Step Size: 0.95       Total Error: 8.50964
# Step Size: 1.00       Total Error: 7.09606
